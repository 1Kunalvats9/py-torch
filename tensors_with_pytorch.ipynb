# %% [markdown]
# <a href="https://colab.research.google.com/github/1Kunalvats9/py-torch/blob/main/tensors_with_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np

# %%
torch.__version__
# Out:
# '2.9.0+cpu'

# %% [markdown]
# ##Lists

# %%
my_list = [1, 2, 3 , 4, 5]

# %%
print(my_list[:5])
# Out:
# [1, 2, 3, 4, 5]
